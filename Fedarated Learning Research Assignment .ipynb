# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Task 1
# The first task is to understand the Ditto paper and reproduce its results. In this task, you must reproduce the robustness (Section 4.1), fairness (Sections 4.2, & 4.3), and accuracy (Section 4.4 ) results on the Fashion MNIST (FMNIST) and FEMNIST (skewed) Datasets provided in Appendix C of the paper. Use the value of lambda given in the paper for these datasets. In the personalization task (e.g., Table 2 of the paper), you can execute any other two baselines (additional to Ditto), say L2SGD and EWC. The code of these base-lines is available in the same GitHub repo.
#
# Prepare a report with the tables and figures of reproduced results. If you feel there were some challenges in reproducing certain results, report them.

# %% [markdown]
# We have chosen two datasets FEMNIST and Fashion Dataset to train and reproduce the results of the paper. We have used the value of lambda to be 0 for local training, 100 for global training and 1 for ditto training. The learning rates and the batch sizes were according to the values given in the paper.

# %% [markdown]
# #### Figure 1

# %%
dataset=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 1/Figure 1.1  - Figure 1.1 .csv')
dataset
# Out:
#    Lambda     Clean
# 0       0  0.888568
# 1       1  0.260061
# 2      25  0.938592
# 3      50  0.938592
# 4      75  0.938592
# 5     100  0.287318

# %%
X=dataset.iloc[:,0].values
y=dataset.iloc[:,1].values
std = np.std(y)

# %%
plt.plot(X, y, linestyle='-', marker='*', markersize=10)
plt.fill_between(X, y - std, y + std, color='blue', alpha=0.3)
plt.ylabel('Test Error')
plt.xlabel('Lambda')
plt.title('Clean')

plt.show()

# %%
dataset=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 1/Figure 1.2 - Sheet1 (2) - Figure 1.2 - Sheet1 (2).csv')
dataset
# Out:
#    Lambda  Adversial
# 0       0   0.949495
# 1       1   0.350970
# 2      25   0.938592
# 3      50   0.938592
# 4      75   0.938592
# 5     100   0.362835

# %%
X=dataset.iloc[:,0].values
y=dataset.iloc[:,1].values
std = np.std(y)

# %%
plt.plot(X, y, linestyle='-', marker='*', markersize=10)
plt.fill_between(X, y - std, y + std, color='blue', alpha=0.3)
plt.ylabel('Test Error')
plt.xlabel('Lambda')
plt.title('Adverial 1 - 20% ')

plt.show()

# %% [markdown]
# Observation - We tried to run the model for different values of lambda like 25, 50 and 75 along with 0, 1 and 100. But it was suprising to get the result that the value of test error was same for rest of the lambdas i.e. 25, 50 and 75. Whereas in the graph represented in the paper, this case was not same.

# %% [markdown]
# #### Figure 3

# %%
dataset_ditto=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 3 and Figure 4/FEMNIST/A1/Fraction of Malacious Devices Vs Test Accuracy Ditto FEMNIST - Sheet1.csv')
dataset_ditto
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.739939                            0.0
# 1       0.649030                            0.2
# 2       0.503127                            0.5
# 3       0.058682                            0.8

# %%
X_ditto=dataset_ditto.iloc[:,1].values
y_ditto=dataset_ditto.iloc[:,0].values

# %%
dataset_global=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 3 and Figure 4/FEMNIST/A1/Fraction of Malacious Devices Vs Test Accuracy Global FEMNIST - Sheet1.csv')
dataset_global
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.712682                            0.0
# 1       0.637165                            0.2
# 2       0.547058                            0.5
# 3       0.091390                            0.8

# %%
X_global=dataset_global.iloc[:,1].values
y_global=dataset_global.iloc[:,0].values

# %%
dataset_local=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 3 and Figure 4/FEMNIST/A1/Fraction of Malacious Devices Vs Test Accuracy Local FEMNIST - Sheet1.csv')
dataset_local
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.111432                            0.0
# 1       0.050505                            0.2
# 2       0.037037                            0.5
# 3       0.025172                            0.8

# %%
X_local=dataset_local.iloc[:,1].values
y_local=dataset_local.iloc[:,0].values

# %%
plt.plot(X_ditto, y_ditto, linestyle='-', marker='*', markersize=10, label='Ditto')
plt.plot(X_global, y_global, linestyle='-', marker='*', markersize=10, label='Global')
plt.plot(X_local, y_local, linestyle='-', marker='*', markersize=10, label='Local')

plt.xlabel('Fraction of Malacious Devices')
plt.ylabel('Test Accuracy	')
plt.title('FEMNIST, A1')
plt.legend()

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
dataset_ditto=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 3 and Figure 4/FEMNIST/A2/Fraction of Malacious Devices Vs Test Accuracy Ditto FEMNIST - Sheet1 (1).csv')
dataset_ditto
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.739939                            0.0
# 1       0.620491                            0.2
# 2       0.453904                            0.5
# 3       0.287638                            0.8

# %%
X_ditto=dataset_ditto.iloc[:,1].values
y_ditto=dataset_ditto.iloc[:,0].values

# %%
dataset_global=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 3 and Figure 4/FEMNIST/A2/Fraction of Malacious Devices Vs Test Accuracy Global FEMNIST - Sheet1 (1).csv')
dataset_global
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.712682                            0.0
# 1       0.567741                            0.2
# 2       0.061408                            0.5
# 3       0.061408                            0.8

# %%
X_global=dataset_global.iloc[:,1].values
y_global=dataset_global.iloc[:,0].values

# %%
dataset_local=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 3 and Figure 4/FEMNIST/A2/Fraction of Malacious Devices Vs Test Accuracy Local FEMNIST - Sheet1 (1).csv')
dataset_local
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.111432                            0.0
# 1       0.050505                            0.2
# 2       0.039763                            0.5
# 3       0.032708                            0.8

# %%
X_local=dataset_local.iloc[:,1].values
y_local=dataset_local.iloc[:,0].values

# %%
plt.plot(X_ditto, y_ditto, linestyle='-', marker='*', markersize=10, label='Ditto')
plt.plot(X_global, y_global, linestyle='-', marker='*', markersize=10, label='Global')
plt.plot(X_local, y_local, linestyle='-', marker='*', markersize=10, label='Local')

plt.xlabel('Fraction of Malacious Devices')
plt.ylabel('Test Accuracy	')
plt.title('FEMNIST, A2')
plt.legend()

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
dataset_ditto=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 3 and Figure 4/FEMNIST/A3/Fraction of Malacious Devices Vs Test Accuracy Ditto FEMNIST - Sheet1.csv')
dataset_ditto
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.739939                           0.00
# 1       0.604618                           0.10
# 2       0.571749                           0.15
# 3       0.062851                           0.20
# 4       0.056277                           0.50
# 5       0.056437                           0.80

# %%
X_ditto=dataset_ditto.iloc[:,1].values
y_ditto=dataset_ditto.iloc[:,0].values

# %%
dataset_global=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 3 and Figure 4/FEMNIST/A3/Fraction of Malacious Devices Vs Test Accuracy Global FEMNIST - Sheet1.csv')
dataset_global
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.712682                           0.00
# 1       0.571749                           0.10
# 2       0.531025                           0.15
# 3       0.061408                           0.20
# 4       0.283790                           0.50
# 5       0.061568                           0.80

# %%
X_global=dataset_global.iloc[:,1].values
y_global=dataset_global.iloc[:,0].values

# %%
dataset_local=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 3 and Figure 4/FEMNIST/A3/Fraction of Malacious Devices Vs Test Accuracy Local FEMNIST - Sheet1.csv')
dataset_local
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.111432                           0.00
# 1       0.103575                           0.10
# 2       0.099086                           0.15
# 3       0.050505                           0.20
# 4       0.037037                           0.50
# 5       0.032708                           0.80

# %%
X_local=dataset_local.iloc[:,1].values
y_local=dataset_local.iloc[:,0].values

# %%
plt.plot(X_ditto, y_ditto, linestyle='-', marker='*', markersize=10, label='Ditto')
plt.plot(X_global, y_global, linestyle='-', marker='*', markersize=10, label='Global')
plt.plot(X_local, y_local, linestyle='-', marker='*', markersize=10, label='Local')

plt.xlabel('Fraction of Malacious Devices')
plt.ylabel('Test Accuracy	')
plt.title('FEMNIST, A3')
plt.legend()

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Observation - We got almost similar result for these adversial by plotting graph between Test accuracy and Fraction of Malacious Devices as tated in the paper. We had the data of the local data as well so we plotted that as well in our report.
#
# More Insigths - In all the graphs it is very clear that the test accuracy for the local model is very less than the other three adversial models. These graphs shows the Robustness of the models (i.e., average test accuracy on benign devices)

# %% [markdown]
# #### Figure 4

# %%
dataset_ditto=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 3 and Figure 4/FEMNIST/A1/Fraction of Malacious Devices Vs Test Accuracy Ditto FEMNIST - Sheet1.csv')
dataset_ditto
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.739939                            0.0
# 1       0.649030                            0.2
# 2       0.503127                            0.5
# 3       0.058682                            0.8

# %%
X_ditto=dataset_ditto.iloc[:,1].values
y_ditto=dataset_ditto.iloc[:,0].values

# %%
dataset_global=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 3 and Figure 4/FEMNIST/A1/Fraction of Malacious Devices Vs Test Accuracy Global FEMNIST - Sheet1.csv')
dataset_global
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.712682                            0.0
# 1       0.637165                            0.2
# 2       0.547058                            0.5
# 3       0.091390                            0.8

# %%
X_global=dataset_global.iloc[:,1].values
y_global=dataset_global.iloc[:,0].values

# %%
plt.plot(X_ditto, y_ditto, linestyle='-', marker='*', markersize=10, label='Ditto')
plt.plot(X_global, y_global, linestyle='-', marker='*', markersize=10, label='Global')

plt.xlabel('Fraction of Malacious Devices')
plt.ylabel('Test Accuracy	')
plt.title('FEMNIST')
plt.legend()

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #### Figure 5

# %%
dataset=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 5/Figure 5.1 - Sheet1.csv')
dataset
# Out:
#    Variance  Test Accuracy
# 0  0.019055       0.739939
# 1  0.018468       0.712682
# 2  0.007258       0.111432

# %%
X=dataset.iloc[:,1].values
y=dataset.iloc[:,0].values

# %%
plt.scatter(X, y)

labels = ['Ditto', 'Global', 'Local']

# Create the scatter plot
plt.scatter(X, y)

# Add labels to each point
for i, label in enumerate(labels):
    plt.annotate(label, (X[i], y[i]))

plt.xlabel('Test Accuracy')
plt.ylabel('Variance')
plt.title('FEMNIST, clean data')


plt.show()

# %%
dataset=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 5/Figure 5.2 - Sheet1.csv')
dataset
# Out:
#    Variance  Test Accuracy
# 0  0.019161       0.649030
# 1  0.017174       0.637165
# 2  0.002354       0.050505

# %%
X=dataset.iloc[:,1].values
y=dataset.iloc[:,0].values

# %%
plt.scatter(X, y)

labels = ['Ditto', 'Global', 'Local']

# Create the scatter plot
plt.scatter(X, y)

# Add labels to each point
for i, label in enumerate(labels):
    plt.annotate(label, (X[i], y[i]))

plt.xlabel('Test Accuracy')
plt.ylabel('Variance')
plt.title('FEMNIST, 20% corrupted devices')


plt.show()

# %% [markdown]
# Observations - From the recieved data fromt the devices, it is evident that while learning global model, that if accuracy is high then larger variance is seen that means either the models are robust but not fair or not even robust.

# %% [markdown]
# #### Table 1

# %%
dataset=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Table 1/FEMNIST/Table 1 - Sheet1.csv')
dataset
# Out:
#    FEMNIST Unnamed: 1        A1      A1.1      A1.2        A2      A2.1  \
# 0  Methods      Clean       20%       50%       80%       20%       50%
# 1    Ditto   0.739939   0.64903  0.503127  0.058682  0.620491  0.453904
# 2    Local   0.111432  0.050505  0.037037  0.025172  0.050505  0.039763
# 3   Global   0.712682  0.637165  0.547058   0.09139  0.567741  0.061408
#
#        A2.2        A3      A3.1      A3.2      A3.3      A3.4
# 0       80%       10%       15%       20%       50%       80%
# 1  0.287638  0.604618  0.571749  0.062851  0.056277  0.056437
# 2  0.032708  0.103575  0.099086  0.050505  0.037037  0.032708
# 3  0.061408  0.571749  0.531025  0.061408   0.28379  0.061568

# %% [markdown]
# Observations - Average test accuracy to see the performance and fairness on the datset. Ditto maybe more fair compared with the other baselines. We recieved a bit near to rewards from these trainings while comaring it by the results of the paper. One reason which might be the reason for this changes are we have trained the models only in 1000 episodes whereas in paper they reported their results for 5000 episodes.

# %% [markdown]
# #### Table 2

# %%
dataset=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Table 2/Table 2 - Sheet1.csv')
dataset
# Out:
#   Methods     Clean  A1 (50%)
# 0  Global  0.712682  0.547058
# 1   Ditto  0.739939  0.503127
# 2   Local  0.111432  0.037037
# 3   L2SGD  0.067340  0.052589
# 4     EWC  0.738817  0.362514

# %% [markdown]
# Observation - Ditto is competitive with EWC and with other it outperforms other personalization methods. Here we have taken the average of test accuricies aross all models so that we can know the performance and fairness.

# %% [markdown]
# ### Fashion Data Set

# %% [markdown]
# #### Figure 3 and Figure 4

# %%
dataset_ditto=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 3 and Figure 4/FMNIST/Ditto-A1 - Sheet1 - Ditto-A1 - Sheet1.csv')
dataset_ditto
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.921095                            0.0
# 1       0.802204                            0.2
# 2       0.626799                            0.5
# 3       0.425893                            0.8

# %%
X_ditto=dataset_ditto.iloc[:,1].values
y_ditto=dataset_ditto.iloc[:,0].values

# %%
dataset_global=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 3 and Figure 4/FMNIST/Global-A1 - Sheet1 - Global-A1 - Sheet1.csv')
dataset_global
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.113115                            0.0
# 1       0.113293                            0.2
# 2       0.112938                            0.5
# 3       0.113293                            0.8

# %%
X_global=dataset_global.iloc[:,1].values
y_global=dataset_global.iloc[:,0].values

# %%
dataset_local=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 3 and Figure 4/FMNIST/Local-A1 - Sheet1 - Local-A1 - Sheet1.csv')
dataset_local
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.832948                            0.0
# 1       0.688289                            0.2
# 2       0.473698                            0.5
# 3       0.270659                            0.8

# %%
X_local=dataset_local.iloc[:,1].values
y_local=dataset_local.iloc[:,0].values

# %%
plt.plot(X_ditto, y_ditto, linestyle='-', marker='*', markersize=10, label='Ditto')
plt.plot(X_global, y_global, linestyle='-', marker='*', markersize=10, label='Global')
plt.plot(X_local, y_local, linestyle='-', marker='*', markersize=10, label='Local')

plt.xlabel('Fraction of Malacious Devices')
plt.ylabel('Test Accuracy	')
plt.title('FMNIST, A1')
plt.legend()

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Observations - This result was not included in the paper so the insigth which we get from the above table is ditto and global follows the same pattern but the test accuracy of ditto is more local. This also shows that accuracy decreases with increasing the the fraction of malacious devices.

# %% [markdown]
# #### Figure 5

# %%
dataset=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/FNIST/Clean - Sheet1.csv')
dataset
# Out:
#    Variance  Test Accuracy
# 0  0.017664       0.832948
# 1  0.023113       0.114480
# 2  0.008110       0.921095

# %%
X=dataset.iloc[:,1].values
y=dataset.iloc[:,0].values

# %%
plt.scatter(X, y)

labels = ['Local', 'Global', 'Ditto']

# Create the scatter plot
plt.scatter(X, y)

# Add labels to each point
for i, label in enumerate(labels):
    plt.annotate(label, (X[i], y[i]))

plt.xlabel('Test Accuracy')
plt.ylabel('Variance')
plt.title('FMNIST, clean data')


plt.show()

# %%
dataset=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/FNIST/A1 20 - Sheet1.csv')
dataset
# Out:
#    Variance  Test Accuracy
# 0  0.008288       0.802204
# 1  0.023630       0.113293
# 2  0.017426       0.688289

# %%
X=dataset.iloc[:,1].values
y=dataset.iloc[:,0].values

# %%
plt.scatter(X, y)

labels = ['Ditto', 'Global', 'Local']

# Create the scatter plot
plt.scatter(X, y)

# Add labels to each point
for i, label in enumerate(labels):
    plt.annotate(label, (X[i], y[i]))

plt.xlabel('Test Accuracy')
plt.ylabel('Variance')
plt.title('FMNIST, 20% corrupted devices')


plt.show()

# %% [markdown]
# Observation - Ditto lies at the lower right corner, which is our preferred region. This result also matches with the result given in the paper.

# %% [markdown]
# #### Table 1

# %%
dataset=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/FNIST/Table1 - Sheet1.csv')
dataset
# Out:
#    Fashion         Clean         A1        A1        A1.1
# 0  Methods         Clean  20.000000  50.000000  80.000000
# 1   Global  0.1131153368   0.113293   0.112938   0.113293
# 2    Local  0.8329482851   0.688289   0.473698   0.270659
# 3   Dittto  0.9210947219   0.802204   0.626799   0.425893

# %% [markdown]
# ## Challenges

# %% [markdown]
# Each training nearly 1 hour for FEMNIST dataset and around 20 hourse for FMNIST dataset for 1000 episodes and as in the paper 5000 episodes were used to train the models and produce the results so it was a bit difficult to match the results in few places.

# %% [markdown]
# # Task 2
# The DITTO algorithm tries to achieve personalization using Algorithm 1. Let’s develop
# another possible algorithm (say FedAvgPer) that works as follows:
# 1. After a global model is learned in simple vanilla federated averaging. The final global model is shared with the clients.
# 2. Now, clients will directly run a few local epochs on their own data and update model parameters. This will add each client’s own personal touch. (We are not adding any constraints of the combined loss objective and regularization between the local and global models as in Ditto).
# 3. Now, after updating model parameters locally, each client has its own personalized FL model.
#
# Compare FedAvgPer with Ditto and other existing baselines in Task 1, i.e., reproduce all the results gathered in the previous task with this updated approach. Is FedAvgPer better than Ditto ? Report your observations.

# %% [markdown]
# The code for FedAvgPer
#
# ```
# import numpy as np
# from tqdm import trange, tqdm
# import tensorflow as tf
# import copy
#
# from .fedbase import BaseFedarated
# from flearn.utils.tf_utils import process_grad, cosine_sim, softmax, norm_grad, l2_clip, get_stdev
# from flearn.utils.model_utils import batch_data, gen_batch, gen_epoch, gen_batch_celeba
# from flearn.utils.language_utils import letter_to_vec, word_to_indices
#
#
# def process_x(raw_x_batch):
#     x_batch = [word_to_indices(word) for word in raw_x_batch]
#     x_batch = np.array(x_batch)
#     return x_batch
#
# def process_y(raw_y_batch):
#     y_batch = [letter_to_vec(c) for c in raw_y_batch]
#     return y_batch
#
#
#
# class Server(BaseFedarated):
#     def __init__(self, params, learner, dataset):
#         print('Using fed avg to Train')
#         self.inner_opt = tf.train.GradientDescentOptimizer(params['learning_rate'])
#         super(Server, self).__init__(params, learner, dataset)
#
#     def train(self):
#         print('Training with {} workers ---'.format(self.clients_per_round))
#
#         np.random.seed(1234567+self.seed)
#         corrupt_id = np.random.choice(range(len(self.clients)), size=self.num_corrupted, replace=False)
#         print(corrupt_id)
#
#         if self.dataset == 'shakespeare':
#             for c in self.clients:
#                 c.train_data['y'], c.train_data['x'] = process_y(c.train_data['y']), process_x(c.train_dat>
#                 c.test_data['y'], c.test_data['x'] = process_y(c.test_data['y']), process_x(c.test_data['x>
#
#         batches = {}
#
#         #client data into batches
#         for idx, c in enumerate(self.clients):
#             if idx in corrupt_id:
#                 c.train_data['y'] = np.asarray(c.train_data['y'])
#                 if self.dataset == 'celeba':
#                     c.train_data['y'] = 1 - c.train_data['y']
#                 elif self.dataset == 'femnist':
#                     c.train_data['y'] = np.random.randint(0, 62, len(c.train_data['y']))
#                 elif self.dataset == 'shakespeare':
#                     c.train_data['y'] = np.random.randint(0, 80, len(c.train_data['y']))
#                 elif self.dataset == "vehicle":
#                     c.train_data['y'] = c.train_data['y'] * -1
#                 elif self.dataset == 'fmnist':
#                     c.train_data['y'] = np.random.randint(0, 10, len(c.train_data['y']))
#
#             if self.dataset == 'celeba':  # need to deal with celeba data loading a bit differently
#                 batches[c] = gen_batch_celeba(c.train_data, self.batch_size, self.num_rounds * self.local_>
#             else:
#                 batches[c] = gen_batch(c.train_data, self.batch_size, self.num_rounds * self.local_iters)
#
#         # vanilla fedavg for learning global model -step 1
#         for i in range(self.num_rounds+1):
#             if i % self.eval_every == 0:
#                 num_test, num_correct_test, test_loss_vector = self.test()  # have set the latest model fo>
#                 avg_test_loss = np.dot(test_loss_vector, num_test) / np.sum(num_test)
#                 num_train, num_correct_train, train_loss_vector = self.train_error()
#                 avg_train_loss = np.dot(train_loss_vector, num_train) / np.sum(num_train)
#
#                 tqdm.write('At round {} training accu: {}, loss: {}'.format(i, np.sum(num_correct_train) *>
#                     num_train), avg_train_loss))
#                 tqdm.write('At round {} test loss: {}'.format(i, avg_test_loss))
#                 tqdm.write('At round {} test accu: {}'.format(i, np.sum(num_correct_test) * 1.0 / np.sum(n>
#                 non_corrupt_id = np.setdiff1d(range(len(self.clients)), corrupt_id)
#                 tqdm.write('At round {} malicious test accu: {}'.format(i, np.sum(
#                     num_correct_test[corrupt_id]) * 1.0 / np.sum(num_test[corrupt_id])))
#                 tqdm.write('At round {} benign test accu: {}'.format(i, np.sum(num_correct_test[non_corrup>
#                 tqdm.write('At round {} variance: {}'.format(i, np.var(
#                     num_correct_test[non_corrupt_id] * 1.0 / num_test[non_corrupt_id])))
#
#             indices, selected_clients = self.select_clients(round=i, corrupt_id=corrupt_id, num_clients=se>
#
#             csolns = []
#             losses = []
#
#             for idx in indices:
#                 c = self.clients[idx]
#
#                 # communicate the latest model
#                 c.set_params(self.latest_model)
#                 weights_before = copy.deepcopy(self.latest_model)
#
#                 loss = c.get_loss()  # training loss
#                 losses.append(loss)
#
#                 for _ in range(self.local_iters):
#                     data_batch = next(batches[c])
#                     _, grads, _ = c.solve_sgd(data_batch)
#
#                 w_global = c.get_params()
#
#                 grads = [(u - v) * 1.0 for u, v in zip(w_global, weights_before)]
#
#                 if idx in corrupt_id:
#                     if self.boosting:  # model replacement
#                         grads = [self.clients_per_round * u for u in grads]
#                     elif self.random_updates:
#                         # send random updates
#                         stdev_ = get_stdev(grads)
#                         grads = [np.random.normal(0, stdev_, size=u.shape) for u in grads]
#
#                 if self.q == 0:
#                     csolns.append(grads)
#                 else:
#                     csolns.append((np.exp(self.q * loss), grads))
#
#             if self.q != 0:
#                 overall_updates = self.aggregate(csolns)
#             else:
#                 if self.gradient_clipping:
#                     csolns = l2_clip(csolns)
#
#                 expected_num_mali = int(self.clients_per_round * self.num_corrupted / len(self.clients))
#
#                 if self.median:
#                     overall_updates = self.median_average(csolns)
#                 elif self.k_norm:
#                     overall_updates = self.k_norm_average(self.clients_per_round - expected_num_mali, csol>
#                 elif self.k_loss:
#                     overall_updates = self.k_loss_average(self.clients_per_round - expected_num_mali, loss>
#                 elif self.krum:
#                     overall_updates = self.krum_average(self.clients_per_round - expected_num_mali - 2, cs>
#                 elif self.mkrum:
#                     m = self.clients_per_round - expected_num_mali
#                     overall_updates = self.mkrum_average(self.clients_per_round - expected_num_mali - 2, m>
#                 elif self.fedmgda:
#                     overall_updates = self.fedmgda_average(csolns)
#                 else:
#                     overall_updates = self.simple_average(csolns)
#
#             self.latest_model = [(u + v) for u, v in zip(self.latest_model, overall_updates)]
#
#         # sending global models to clients: step2
#         for idx in range(len(self.clients)):
#
#                 c = self.clients[idx]
#                 # communicate the latest model
#                 c.set_params(self.latest_model)
#                 weights_before = copy.deepcopy(self.latest_model)
#                 loss = c.get_loss()  # training loss
#                 losses.append(loss)
#
#                 # generating batch
#                 if self.dataset == 'celeba':  # need to deal with celeba data loading a bit differently
#                     batch = gen_batch_celeba(c.train_data, self.batch_size, self.num_rounds * self.local_i>
#                 else:
#                     batch = gen_batch(c.train_data, self.batch_size, self.num_rounds * self.local_iters)
#
#                 # training each client on their for personalization
#                 for _ in range(10):
#                     data_batch = next(batch)
#                     _, grads, _ = c.solve_sgd(data_batch)
#
#                 # updating trained personalized models to clients
#                 self.clients[idx]=c
#
#
#         num_test, num_correct_test, test_loss_vector = self.test()  # have set the latest model for all cl>
#         avg_test_loss = np.dot(test_loss_vector, num_test) / np.sum(num_test)
#         num_train, num_correct_train, train_loss_vector = self.train_error()
#         avg_train_loss = np.dot(train_loss_vector, num_train) / np.sum(num_train)
#
#         tqdm.write('Perfedavg training accuracy : {} , loss {} '.format(np.sum(num_correct_train) * 1.0 / >
#             num_train), avg_train_loss))
#         tqdm.write('Perfedavg test loss {} '.format( avg_test_loss))
#         tqdm.write('Perfedavg test accuracy {} '.format(np.sum(num_correct_test) * 1.0 / np.sum(num_test)))
#         non_corrupt_id = np.setdiff1d(range(len(self.clients)), corrupt_id)
#         tqdm.write('Perfedavg malicious test accu: {}'.format(np.sum(
#             num_correct_test[corrupt_id]) * 1.0 / np.sum(num_test[corrupt_id])))
#         tqdm.write('Perfedavg benign test accu: {}'.format(np.sum(num_correct_test[non_corrupt_id]) * 1.0 >
#         tqdm.write('Perfedavg variance: {}'.format(np.var(
#             num_correct_test[non_corrupt_id] * 1.0 / num_test[non_corrupt_id])))
#
# ```
#
# Along with this, we have changed the main.py file as well to run this optimizer. We trained this for different values of adversials and clean data for ditto. Below are the reported observations for this.

# %% [markdown]
# #### Figure 3

# %%
dataset_ditto=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 3 and Figure 4/FEMNIST/A1/Fraction of Malacious Devices Vs Test Accuracy Ditto FEMNIST - Sheet1.csv')
dataset_ditto
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.739939                            0.0
# 1       0.649030                            0.2
# 2       0.503127                            0.5
# 3       0.058682                            0.8

# %%
X_ditto=dataset_ditto.iloc[:,1].values
y_ditto=dataset_ditto.iloc[:,0].values

# %%
dataset_global=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 3 and Figure 4/FEMNIST/A1/Fraction of Malacious Devices Vs Test Accuracy Global FEMNIST - Sheet1.csv')
dataset_global
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.712682                            0.0
# 1       0.637165                            0.2
# 2       0.547058                            0.5
# 3       0.091390                            0.8

# %%
X_global=dataset_global.iloc[:,1].values
y_global=dataset_global.iloc[:,0].values

# %%
dataset_local=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 3 and Figure 4/FEMNIST/A1/Fraction of Malacious Devices Vs Test Accuracy Local FEMNIST - Sheet1.csv')
dataset_local
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.111432                            0.0
# 1       0.050505                            0.2
# 2       0.037037                            0.5
# 3       0.025172                            0.8

# %%
X_local=dataset_local.iloc[:,1].values
y_local=dataset_local.iloc[:,0].values

# %%
dataset_perfedavg=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/TASK2/Figure 3 and Figure 4/A1/Fraction of Malacious Devices Vs Test Accuracy PerFedAvg FEMNIST - Sheet1 - Fraction of Malacious Devices Vs Test Accuracy Ditto FEMNIST - Sheet1.csv')
dataset_perfedavg
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.729517                            0.0
# 1       0.698894                            0.2
# 2       0.620010                            0.5
# 3       0.346801                            0.8

# %%
X_perfedavg=dataset_perfedavg.iloc[:,1].values
y_perfedavg=dataset_perfedavg.iloc[:,0].values

# %%
plt.plot(X_ditto, y_ditto, linestyle='-', marker='*', markersize=10, label='Ditto')
plt.plot(X_global, y_global, linestyle='-', marker='*', markersize=10, label='Global')
plt.plot(X_local, y_local, linestyle='-', marker='*', markersize=10, label='Local')
plt.plot(X_perfedavg, y_perfedavg, linestyle='-', marker='*', markersize=10, label='PerFedAvg')

plt.xlabel('Fraction of Malacious Devices')
plt.ylabel('Test Accuracy	')
plt.title('FEMNIST, A1')
plt.legend()

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
dataset_ditto=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 3 and Figure 4/FEMNIST/A2/Fraction of Malacious Devices Vs Test Accuracy Ditto FEMNIST - Sheet1 (1).csv')
dataset_ditto
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.739939                            0.0
# 1       0.620491                            0.2
# 2       0.453904                            0.5
# 3       0.287638                            0.8

# %%
X_ditto=dataset_ditto.iloc[:,1].values
y_ditto=dataset_ditto.iloc[:,0].values

# %%
dataset_global=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 3 and Figure 4/FEMNIST/A2/Fraction of Malacious Devices Vs Test Accuracy Global FEMNIST - Sheet1 (1).csv')
dataset_global
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.712682                            0.0
# 1       0.567741                            0.2
# 2       0.061408                            0.5
# 3       0.061408                            0.8

# %%
X_global=dataset_global.iloc[:,1].values
y_global=dataset_global.iloc[:,0].values

# %%
dataset_local=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 3 and Figure 4/FEMNIST/A2/Fraction of Malacious Devices Vs Test Accuracy Local FEMNIST - Sheet1 (1).csv')
dataset_local
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.111432                            0.0
# 1       0.050505                            0.2
# 2       0.039763                            0.5
# 3       0.032708                            0.8

# %%
X_local=dataset_local.iloc[:,1].values
y_local=dataset_local.iloc[:,0].values

# %%
dataset_perfedavg=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/TASK2/Figure 3 and Figure 4/A2/Fraction of Malacious Devices Vs Test Accuracy PerFedAvg FEMNIST - Sheet1 (1) - Fraction of Malacious Devices Vs Test Accuracy Ditto FEMNIST - Sheet1 (1).csv')
dataset_perfedavg
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.729517                            0.0
# 1       0.697130                            0.2
# 2       0.629309                            0.5
# 3       0.480519                            0.8

# %%
X_perfedavg=dataset_perfedavg.iloc[:,1].values
y_perfedavg=dataset_perfedavg.iloc[:,0].values

# %%
plt.plot(X_ditto, y_ditto, linestyle='-', marker='*', markersize=10, label='Ditto')
plt.plot(X_global, y_global, linestyle='-', marker='*', markersize=10, label='Global')
plt.plot(X_local, y_local, linestyle='-', marker='*', markersize=10, label='Local')
plt.plot(X_perfedavg, y_perfedavg, linestyle='-', marker='*', markersize=10, label='PerFedAvg')

plt.xlabel('Fraction of Malacious Devices')
plt.ylabel('Test Accuracy	')
plt.title('FEMNIST, A2')
plt.legend()

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
dataset_ditto=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/TASK2/Figure 3 and Figure 4/A3/Fraction of Malacious Devices Vs Test Accuracy Ditto FEMNIST - Sheet1 - Fraction of Malacious Devices Vs Test Accuracy Ditto FEMNIST - Sheet1.csv')
dataset_ditto
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.739939                            0.0
# 1       0.062851                            0.2
# 2       0.056277                            0.5
# 3       0.056437                            0.8

# %%
X_ditto=dataset_ditto.iloc[:,1].values
y_ditto=dataset_ditto.iloc[:,0].values

# %%
dataset_global=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/TASK2/Figure 3 and Figure 4/A3/Fraction of Malacious Devices Vs Test Accuracy Global FEMNIST - Sheet1 - Fraction of Malacious Devices Vs Test Accuracy Global FEMNIST - Sheet1.csv')
dataset_global
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.712682                            0.0
# 1       0.061408                            0.2
# 2       0.283790                            0.5
# 3       0.061568                            0.8

# %%
X_global=dataset_global.iloc[:,1].values
y_global=dataset_global.iloc[:,0].values

# %%
dataset_perfedavg=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/TASK2/Figure 3 and Figure 4/A3/Fraction of Malacious Devices Vs Test Accuracy Local FEMNIST - Sheet1 - Fraction of Malacious Devices Vs Test Accuracy Local FEMNIST - Sheet1 (1).csv')
dataset_perfedavg
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.729517                            0.0
# 1       0.461921                            0.2
# 2       0.170114                            0.5
# 3       0.059003                            0.8

# %%
X_perfedavg=dataset_perfedavg.iloc[:,1].values
y_perfedavg=dataset_perfedavg.iloc[:,0].values

# %%
dataset_local=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/TASK2/Figure 3 and Figure 4/A3/Fraction of Malacious Devices Vs Test Accuracy Local FEMNIST - Sheet1 - Fraction of Malacious Devices Vs Test Accuracy Local FEMNIST - Sheet1.csv')
dataset_local
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.111432                            0.0
# 1       0.050505                            0.2
# 2       0.037037                            0.5
# 3       0.032708                            0.8

# %%
X_local=dataset_local.iloc[:,1].values
y_local=dataset_local.iloc[:,0].values

# %%
plt.plot(X_ditto, y_ditto, linestyle='-', marker='*', markersize=10, label='Ditto')
plt.plot(X_global, y_global, linestyle='-', marker='*', markersize=10, label='Global')
plt.plot(X_local, y_local, linestyle='-', marker='*', markersize=10, label='Local')
plt.plot(X_perfedavg, y_perfedavg, linestyle='-', marker='*', markersize=10, label='PerFedAvg')

plt.xlabel('Fraction of Malacious Devices')
plt.ylabel('Test Accuracy	')
plt.title('FEMNIST, A3')
plt.legend()

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Observation - The performance of PerFedAvg Algorithm is better than ditto in all adversial and better than local and global too.

# %% [markdown]
# #### Figure 4

# %%
dataset_ditto=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 3 and Figure 4/FEMNIST/A1/Fraction of Malacious Devices Vs Test Accuracy Ditto FEMNIST - Sheet1.csv')
dataset_ditto
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.739939                            0.0
# 1       0.649030                            0.2
# 2       0.503127                            0.5
# 3       0.058682                            0.8

# %%
X_ditto=dataset_ditto.iloc[:,1].values
y_ditto=dataset_ditto.iloc[:,0].values

# %%
dataset_global=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 1/Figure 3 and Figure 4/FEMNIST/A1/Fraction of Malacious Devices Vs Test Accuracy Global FEMNIST - Sheet1.csv')
dataset_global
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.712682                            0.0
# 1       0.637165                            0.2
# 2       0.547058                            0.5
# 3       0.091390                            0.8

# %%
X_global=dataset_global.iloc[:,1].values
y_global=dataset_global.iloc[:,0].values

# %%
dataset_perfedavg=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/TASK2/Figure 3 and Figure 4/A1/Fraction of Malacious Devices Vs Test Accuracy PerFedAvg FEMNIST - Sheet1 - Fraction of Malacious Devices Vs Test Accuracy Ditto FEMNIST - Sheet1.csv')
dataset_perfedavg
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.729517                            0.0
# 1       0.698894                            0.2
# 2       0.620010                            0.5
# 3       0.346801                            0.8

# %%
X_perfedavg=dataset_perfedavg.iloc[:,1].values
y_perfedavg=dataset_perfedavg.iloc[:,0].values

# %%
plt.plot(X_ditto, y_ditto, linestyle='-', marker='*', markersize=10, label='Ditto')
plt.plot(X_global, y_global, linestyle='-', marker='*', markersize=10, label='Global')
plt.plot(X_perfedavg, y_perfedavg, linestyle='-', marker='*', markersize=10, label='PerFedAvg')

plt.xlabel('Fraction of Malacious Devices')
plt.ylabel('Test Accuracy	')
plt.title('FEMNIST, A1')
plt.legend()

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Obeservation - On comparion with previous algorithms the test accuracy is more than other methods.

# %% [markdown]
# #### Figure 5

# %%
dataset=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/TASK2/Figure 5.1 - Sheet1 - Figure 5.1 - Sheet1.csv')
dataset
# Out:
#    Variance  Test Accuracy
# 0  0.019055       0.739939
# 1  0.018468       0.712682
# 2  0.007258       0.111432
# 3  0.016764       0.729517

# %%
X=dataset.iloc[:,1].values
y=dataset.iloc[:,0].values

# %%
plt.scatter(X, y)

labels = ['Ditto', 'Global', 'Local','PerFedAvg']

# Create the scatter plot
plt.scatter(X, y)

# Add labels to each point
for i, label in enumerate(labels):
    plt.annotate(label, (X[i], y[i]))

plt.xlabel('Test Accuracy')
plt.ylabel('Variance')
plt.title('FEMNIST, clean data')


plt.show()

# %%
dataset=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/TASK2/Figure 5.2 - Sheet1 - Figure 5.2 - Sheet1.csv')
dataset
# Out:
#    Variance  Test Accuracy
# 0  0.019161       0.649030
# 1  0.017174       0.637165
# 2  0.002354       0.050505
# 3  0.017890       0.698894

# %%
X=dataset.iloc[:,1].values
y=dataset.iloc[:,0].values

# %%
plt.scatter(X, y)

labels = ['Ditto', 'Global', 'Local','PerFedAvg']

# Create the scatter plot
plt.scatter(X, y)

# Add labels to each point
for i, label in enumerate(labels):
    plt.annotate(label, (X[i], y[i]))

plt.xlabel('Test Accuracy')
plt.ylabel('Variance')
plt.title('FEMNIST, 20% corrupted devices')


plt.show()

# %% [markdown]
# Observation - Although the test accuracy is maximum among all but the variance is less tha ditto this violates the observation given in the paper that with higher accuracy there is larger variance.

# %% [markdown]
# #### Table 1

# %%
dataset=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/TASK2/Table 1 - Sheet1 - Table 1 - Sheet1.csv')
dataset
# Out:
#      FEMNIST         Clean            A1        A1.1          A1.2  \
# 0    Methods         Clean           20%         50%           80%
# 1      Ditto      0.739939       0.64903    0.503127      0.058682
# 2      Local      0.111432      0.050505    0.037037      0.025172
# 3     Global      0.712682      0.637165    0.547058       0.09139
# 4  FedAvgPer  0.7295173962  0.6988936989  0.62000962  0.3441739824
#
#              A2          A2.1          A2.2            A3           A3.1  \
# 0           20%           50%           80%           20%            50%
# 1      0.620491      0.453904      0.287638      0.062851       0.056277
# 2      0.050505      0.039763      0.032708      0.050505       0.037037
# 3      0.567741      0.061408      0.061408      0.061408        0.28379
# 4  0.6971300305  0.4805194805  0.6293089626  0.4619207953  0.05900272567
#
#            A3.2
# 0           80%
# 1      0.056437
# 2      0.032708
# 3      0.061568
# 4  0.1701138368

# %% [markdown]
# Observation - We can see that except clean model FedAvgPer performs better than even ditto for rest all models and adversials.

# %% [markdown]
# #### Table 2

# %%
dataset=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/TASK2/Table 2 - Sheet1 - Table 2 - Sheet1.csv')
dataset
# Out:
#      Methods     Clean  A1 (50%)
# 0     Global  0.712682  0.547058
# 1      Ditto  0.739939  0.503127
# 2      Local  0.111432  0.037037
# 3      L2SGD  0.067340  0.052589
# 4        EWC  0.738817  0.362514
# 5  PreFedAvg  0.729517  0.620010

# %% [markdown]
# # Task 3
# Now consider another dataset called the ADULT dataset available at https:/ archive.ics.uci.edu/ml/datasets/adult. It is a census dataset usually used to predict whether income exceeds 50K per year. Let us consider a scenario where we have clients in different countries/regions, each generating their own data. To mimic this scenario, divide the complete dataset into clients based on column ‘native-country’. Further, consider a fairness metric called Equal Opportunity. Equalized opportunity means matching the true positive rates (TPR) for different values of a protected/sensitive attribute such as for ADULT dataset matching TPR for income prediction for different values of gender. If or both MALE and FEMALE, the TPR rates are same then the model is fair otherwise its unfair.
#
# Here, the fairness criteria has been evaluated based on the sensitive attribute column ‘gender’ in the dataset.
#
# Your task is to create a new loss function considering the combination of accuracy and Equal Opportunity fairness metrics (considering gender) for improving personalization and fairness performance. Report the different results for this approach.
#
# (Note that you can use the base model as SVM for the adult dataset instead of CNN used in previous parts for FMNIST, FEMINST image datasets).

# %% [markdown]
# Code for creating the json dataset from the csv file so that it gets in same format with other attributes
#
#
#
# ```
# import pandas as pd
# import numpy as np
# import json
# from sklearn.preprocessing import LabelEncoder
# def df_to_json(df, filename):
#
#     # Convert 'income' column to categorical data type
#     df['income'] = df['income'].astype('category')
#
#     # Identify categorical columns
#     categorical_cols = [col for col in df.columns if not pd.api.types.is_numeric_dtype(df[col])]
#     print(categorical_cols)
#     # Convert binary categorical columns to numeric binary representation
#     encoders = {col: LabelEncoder() for col in categorical_cols}
#
#     # Encode each categorical column
#     for col in categorical_cols:
#         df[col] = encoders[col].fit_transform(df[col])
#         print(df.head)
#     grouped = df.groupby('native_country')
#     data = {
#         'num_samples': [],
#         'users': [],
#         'user_data': {}
#     }
#     for cnt, sdf in grouped:
#         sdf = sdf.drop(columns=['native_country'])
#         sdf['income'] = sdf['income'].astype('category')
#         data['num_samples'].append(len(sdf))
#         data['users'].append(cnt)
#
#         # Add feature and target data to dictionary for current country
#         x_data = sdf.drop(columns=['income']).values.astype(np.float32).tolist()
#         y_data = sdf['income'].cat.codes.values.astype(np.float32).reshape(-1, 1).tolist()
#         data['user_data'][cnt] = {'x': x_data, 'y': y_data}
#
#     # Save data dictionary as JSON file
#     with open(filename, 'w') as f:
#         json.dump(data, f)
#
#
# #Loading datasets and converting to json
# col_names=['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status',
#     'occupation', 'relationship', 'race', 'sex', 'capital_gain', 'capital_loss',
#     'hours_per_week', 'native_country', 'income']
#
# train_df = pd.read_csv('adult.data', header=None, names=col_names)
# test_df  = pd.read_csv('adult.test', header=None, names=col_names)
# train_df.replace(' ?', np.nan, inplace=True)
# test_df.replace(' ?', np.nan, inplace=True)
# train_df= train_df.dropna()
# test_df= test_df.dropna()
# countries = [x for x in train_df.native_country.unique() if x in test_df.native_country.unique()]
# print(test_df.head)
# train_df = train_df[train_df.native_country.isin(countries)]
# print(test_df.head)
# test_df = test_df[test_df.native_country.isin(countries)]
#
# # Convert filtered dataframes to json
# df_to_json(train_df, "mytrain.json")
# df_to_json(test_df, "mytest.json")
# ```

# %% [markdown]
# The code for SVM which was used to train the model along with the loass function is written below.
#
#
# ```
# import numpy as np
# import tensorflow as tf
# from tqdm import trange
#
# from flearn.utils.model_utils import batch_data, gen_batch
# from flearn.utils.tf_utils import graph_size
# from flearn.utils.tf_utils import process_grad
#
#
# class Model(object):
#     def __init__(self, num_classes, q, optimizer, seed=1):
#
#         # params
#         self.num_classes = num_classes
#
#         # create computation graph
#         self.graph = tf.Graph()
#         with self.graph.as_default():
#             tf.set_random_seed(123+seed)
#             self.features, self.labels, self.train_op, self.grads, self.eval_metric_ops, self.loss, self.predictions = self.create_model(q, optimizer)
#             self.saver = tf.train.Saver()
#         self.sess = tf.Session(graph=self.graph)
#
#         # find memory footprint and compute cost of the model
#         self.size = graph_size(self.graph)
#         with self.graph.as_default():
#             self.sess.run(tf.global_variables_initializer())
#             metadata = tf.RunMetadata()
#             opts = tf.profiler.ProfileOptionBuilder.float_operation()
#
#     def create_model(self, q, optimizer):
#         """Model function for Logistic Regression."""
#         features = tf.placeholder(tf.float32, shape=[None, 62], name='features')
#         labels = tf.placeholder(tf.float32, shape=[None, 1], name='labels')
#
#
#         W = tf.Variable(tf.zeros([62, 1]))
#         b = tf.Variable(tf.zeros([1]))
#         y_pred = tf.matmul(features, W) + b
#
#         l2_reg = 0.01 * tf.reduce_sum(tf.square(W))
#         temp = tf.maximum(tf.zeros_like(labels), 1 - labels * y_pred)
#         mask = tf.where(tf.equal(tf.sign(features[:, 3]), tf.constant(1.0)), tf.ones_like(labels), tf.zeros_like(labels))
#         loss = tf.reduce_mean(tf.multiply(temp, mask)) + l2_reg
#
#         grads_and_vars = optimizer.compute_gradients(loss)
#         grads, _ = zip(*grads_and_vars)
#         train_op = optimizer.apply_gradients(grads_and_vars, global_step=tf.train.get_global_step())
#
#         eval_metric_ops = tf.count_nonzero(tf.equal(labels, tf.sign(y_pred)))
#         return features, labels, train_op, grads, eval_metric_ops, loss, tf.sign(y_pred)
#
#     def set_params(self, model_params=None):
#         if model_params is not None:
#             with self.graph.as_default():
#                 all_vars = tf.trainable_variables()
#                 for variable, value in zip(all_vars, model_params):
#                     variable.load(value, self.sess)
#
#     def get_params(self):
#         with self.graph.as_default():
#             model_params = self.sess.run(tf.trainable_variables())
#         return model_params
#
#     def get_gradients(self, data, model_len):
#
#         grads = np.zeros(model_len)
#         num_samples = len(data['y'])
#
#         with self.graph.as_default():
#             model_grads = self.sess.run(self.grads,
#                 feed_dict={self.features: data['x'], self.labels: data['y']})
#             grads = process_grad(model_grads)
#
#         return num_samples, grads
#
#     def get_loss(self, data):
#         with self.graph.as_default():
#             loss = self.sess.run(self.loss, feed_dict={self.features: data['x'], self.labels: data['y']})
#         return loss
#
#     def solve_inner(self, data, num_epochs=1, batch_size=32):
#         '''Solves local optimization problem'''
#         for _ in range(num_epochs):
#             for X, y in batch_data(data, batch_size):
#                 with self.graph.as_default():
#                     _, pred = self.sess.run([self.train_op, self.predictions],
#                         feed_dict={self.features: X, self.labels: y})
#         soln = self.get_params()
#         comp = num_epochs * (len(data['y'])//batch_size) * batch_size * self.flops
#         return soln, comp
#
#     def solve_sgd(self, mini_batch_data):
#         with self.graph.as_default():
#             grads, loss, _ = self.sess.run([self.grads, self.loss, self.train_op],
#                                     feed_dict={self.features: mini_batch_data[0], self.labels: mini_batch_data[1]})
#
#         weights = self.get_params()
#         return grads, loss, weights
#
#     def test(self, data):
#         '''
#         Args:
#             data: dict of the form {'x': [list], 'y': [list]}
#         '''
#         with self.graph.as_default():
#             tot_correct, loss = self.sess.run([self.eval_metric_ops, self.loss],
#                 feed_dict={self.features: data['x'], self.labels: data['y']})
#         return tot_correct, loss
#
#     def close(self):
#         self.sess.close()
# ```

# %% [markdown]
# #### Results on various values of malacious devices in different adversials

# %%
dataset_adult=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 3/Figure 3 and Figure 4/Adult-A1 - Sheet1.csv')
dataset_adult
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.245684                            0.0
# 1       0.245684                            0.2
# 2       0.245684                            0.5
# 3       0.245684                            0.8

# %%
X_adult=dataset_adult.iloc[:,1].values
y_adult=dataset_adult.iloc[:,0].values

# %%
plt.plot(X_adult, y_adult, linestyle='-', marker='*', markersize=10, label='Adult_SVM')

plt.xlabel('Fraction of Malacious Devices')
plt.ylabel('Test Accuracy	')
plt.title('Adult, A1')
plt.legend()

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
dataset_adult=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 3/Figure 3 and Figure 4/Adult-A2 - Sheet1.csv')
dataset_adult
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.245684                            0.0
# 1       0.245684                            0.2
# 2       0.245684                            0.5
# 3       0.243758                            0.8

# %%
X_adult=dataset_adult.iloc[:,1].values
y_adult=dataset_adult.iloc[:,0].values

# %%
plt.plot(X_adult, y_adult, linestyle='-', marker='*', markersize=10, label='Adult_SVM')

plt.xlabel('Fraction of Malacious Devices')
plt.ylabel('Test Accuracy	')
plt.title('Adult, A2')
plt.legend()

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
dataset_adult=pd.read_csv('/content/drive/MyDrive/Logfiles_ML_Assignment_4/Task 3/Figure 3 and Figure 4/Adult-A3 - Sheet1.csv')
dataset_adult
# Out:
#    Test Accuracy  Fraction of Malacious Devices
# 0       0.245684                           0.00
# 1       0.245684                           0.10
# 2       0.245684                           0.15
# 3       0.245684                           0.20

# %%
X_adult=dataset_adult.iloc[:,1].values
y_adult=dataset_adult.iloc[:,0].values

# %%
plt.plot(X_adult, y_adult, linestyle='-', marker='*', markersize=10, label='Adult_SVM')


plt.xlabel('Fraction of Malacious Devices')
plt.ylabel('Test Accuracy	')
plt.title('Adult, A3')
plt.legend()

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Observation - For A1 adversial and A3 adversial the test accuracy did not changed at all. Whereas for A2 adversial test accuracy drops for 80% fraction of malacious device.

# %% [markdown]
# # Task 4
#
# In real-world decision-making systems, classification models must not only be accurate but also indicate when they are likely to be incorrect. Specifically, a model should provide a calibrated confidence measure in addition to its prediction. In other words, the probability associated with the predicted class label should reflect its ground truth correctness likelihood. Good confidence estimates for the predicted label provide a valuable extra bit of information to establish trustworthiness with the user – especially for neural networks, whose classification decisions are often difficult to interpret.
#
# A metric to analyze the level of calibration of a model is Maximum Calibration Error (MCE) (refer to Equation 4 in paper [1]).
#
# Your task is to report the MCE for different personalized models obtained using DITTO (Algorithm 1 in [2]).
#
# Further, calibrate the local client models using the Platt scaling method in the paper [1] (Section 4.1) and again compare the calibration errors before and after applying Platt scaling calibration. Is there any advantage of calibration for the clients?

# %% [markdown]
# The code to calculate the MCE Error for different personalized models using DITTO.
# ```
# import numpy as np
# from tqdm import trange, tqdm
# import tensorflow as tf
# import copy
#
# from .fedbase import BaseFedarated
# from flearn.utils.tf_utils import process_grad, cosine_sim, softmax, norm_grad, l2_clip, get_stdev
# from flearn.utils.model_utils import batch_data, gen_batch, gen_epoch, gen_batch_celeba
# from flearn.utils.language_utils import letter_to_vec, word_to_indices
#
#
# def process_x(raw_x_batch):
#     x_batch = [word_to_indices(word) for word in raw_x_batch]
#     x_batch = np.array(x_batch)
#     return x_batch
#
# def process_y(raw_y_batch):
#     y_batch = [letter_to_vec(c) for c in raw_y_batch]
#     return y_batch
#
#
#
# class Server(BaseFedarated):
#     def __init__(self, params, learner, dataset):
#         print('Using fed avg to Train')
#         self.inner_opt = tf.train.GradientDescentOptimizer(params['learning_rate'])
#         super(Server, self).__init__(params, learner, dataset)
#
#     def train(self):
#         print('Training with {} workers ---'.format(self.clients_per_round))
#
#         np.random.seed(1234567+self.seed)
#         corrupt_id = np.random.choice(range(len(self.clients)), size=self.num_corrupted, replace=False)
#         print(corrupt_id)
#
#         if self.dataset == 'shakespeare':
#             for c in self.clients:
#                 c.train_data['y'], c.train_data['x'] = process_y(c.train_data['y']), process_x(c.train_data['x'])
#                 c.test_data['y'], c.test_data['x'] = process_y(c.test_data['y']), process_x(c.test_data['x'])
#
#         batches = {}
#
#         #client data into batches
#         for idx, c in enumerate(self.clients):
#             if idx in corrupt_id:
#                 c.train_data['y'] = np.asarray(c.train_data['y'])
#                 if self.dataset == 'celeba':
#                     c.train_data['y'] = 1 - c.train_data['y']
#                 elif self.dataset == 'femnist':
#                     c.train_data['y'] = np.random.randint(0, 62, len(c.train_data['y']))
#                 elif self.dataset == 'shakespeare':
#                     c.train_data['y'] = np.random.randint(0, 80, len(c.train_data['y']))
#                 elif self.dataset == "vehicle":
#                     c.train_data['y'] = c.train_data['y'] * -1
#                 elif self.dataset == 'fmnist':
#                     c.train_data['y'] = np.random.randint(0, 10, len(c.train_data['y']))
#
#             if self.dataset == 'celeba':  # need to deal with celeba data loading a bit differently
#                 batches[c] = gen_batch_celeba(c.train_data, self.batch_size, self.num_rounds * self.local_iters)
#             else:
#                 batches[c] = gen_batch(c.train_data, self.batch_size, self.num_rounds * self.local_iters)
#
#         # vanilla fedavg for learning global model -step 1
#         for i in range(self.num_rounds+1):
#             if i % self.eval_every == 0:
#                 num_test, num_correct_test, test_loss_vector = self.test()  # have set the latest model for all clients
#                 avg_test_loss = np.dot(test_loss_vector, num_test) / np.sum(num_test)
#                 num_train, num_correct_train, train_loss_vector = self.train_error()
#                 avg_train_loss = np.dot(train_loss_vector, num_train) / np.sum(num_train)
#
#                 tqdm.write('At round {} training accu: {}, loss: {}'.format(i, np.sum(num_correct_train) * 1.0 / np.sum(
#                     num_train), avg_train_loss))
#                 tqdm.write('At round {} test loss: {}'.format(i, avg_test_loss))
#                 tqdm.write('At round {} test accu: {}'.format(i, np.sum(num_correct_test) * 1.0 / np.sum(num_test)))
#                 non_corrupt_id = np.setdiff1d(range(len(self.clients)), corrupt_id)
#                 tqdm.write('At round {} malicious test accu: {}'.format(i, np.sum(
#                     num_correct_test[corrupt_id]) * 1.0 / np.sum(num_test[corrupt_id])))
#                 tqdm.write('At round {} benign test accu: {}'.format(i, np.sum(num_correct_test[non_corrupt_id]) * 1.0 / np.sum(num_test[non_corrupt_id])))
#                 tqdm.write('At round {} variance: {}'.format(i, np.var(
#                     num_correct_test[non_corrupt_id] * 1.0 / num_test[non_corrupt_id])))
#
#             indices, selected_clients = self.select_clients(round=i, corrupt_id=corrupt_id, num_clients=self.clients_per_round)
#
#             csolns = []
#             losses = []
#
#             for idx in indices:
#                 c = self.clients[idx]
#
#                 # communicate the latest model
#                 c.set_params(self.latest_model)
#                 weights_before = copy.deepcopy(self.latest_model)
#
#                 loss = c.get_loss()  # training loss
#                 losses.append(loss)
#
#                 for _ in range(self.local_iters):
#                     data_batch = next(batches[c])
#                     _, grads, _ = c.solve_sgd(data_batch)
#
#                 w_global = c.get_params()
#
#                 grads = [(u - v) * 1.0 for u, v in zip(w_global, weights_before)]
#
#                 if idx in corrupt_id:
#                     if self.boosting:  # model replacement
#                         grads = [self.clients_per_round * u for u in grads]
#                     elif self.random_updates:
#                         # send random updates
#                         stdev_ = get_stdev(grads)
#                         grads = [np.random.normal(0, stdev_, size=u.shape) for u in grads]
#
#                 if self.q == 0:
#                     csolns.append(grads)
#                 else:
#                     csolns.append((np.exp(self.q * loss), grads))
#
#             if self.q != 0:
#                 overall_updates = self.aggregate(csolns)
#             else:
#                 if self.gradient_clipping:
#                     csolns = l2_clip(csolns)
#
#                 expected_num_mali = int(self.clients_per_round * self.num_corrupted / len(self.clients))
#
#                 if self.median:
#                     overall_updates = self.median_average(csolns)
#                 elif self.k_norm:
#                     overall_updates = self.k_norm_average(self.clients_per_round - expected_num_mali, csolns)
#                 elif self.k_loss:
#                     overall_updates = self.k_loss_average(self.clients_per_round - expected_num_mali, losses, csolns)
#                 elif self.krum:
#                     overall_updates = self.krum_average(self.clients_per_round - expected_num_mali - 2, csolns)
#                 elif self.mkrum:
#                     m = self.clients_per_round - expected_num_mali
#                     overall_updates = self.mkrum_average(self.clients_per_round - expected_num_mali - 2, m, csolns)
#                 elif self.fedmgda:
#                     overall_updates = self.fedmgda_average(csolns)
#                 else:
#                     overall_updates = self.simple_average(csolns)
#
#             self.latest_model = [(u + v) for u, v in zip(self.latest_model, overall_updates)]
#
#         # MCE Error Calculation: step2
#         _, num_correct_test, _ = self.test()  # have set the latest model for all clients
#         num_bins = 10
#         bin_boundaries = np.linspace(0, 1, num_bins+1)
#         bin_confidences = [[] for _ in range(num_bins)]
#         bin_accuracies = [[] for _ in range(num_bins)]
#         for c in self.clients:
#             _, c_correct_test, c_confidence = c.test()  # have set the latest model for this client
#             for i in range(num_bins):
#                 bin_indices = np.where((bin_boundaries[i] <= c_confidence) & (c_confidence < bin_boundaries[i+1]))[0]
#                 if len(bin_indices) > 0:
#                     bin_confidences[i] += list(np.atleast_1d(c_confidence[bin_indices]))
#                     bin_accuracies[i] += list(np.atleast_1d(c_correct_test[bin_indices]))
#         bin_confs = [np.mean(bin_confidences[i]) if len(bin_confidences[i]) > 0 else 0 for i in range(num_bins)]
#         bin_accs = [np.mean(bin_accuracies[i]) if len(bin_accuracies[i]) > 0 else 0 for i in range(num_bins)]
#         max_calibration_error = max([abs(bin_accs[i] - bin_confs[i]) for i in range(num_bins)])
#         tqdm.write('At round {}, maximum calibration error: {}'.format(i, max_calibration_error))
#
# ```

# %%
print("After training Ditto on all clean devices, we get Maximum Calibration Error of 9",)
# Out:
# After training Ditto on all clean devices, we get Maximum Calibration Error of 9

# %% [markdown]
# Logfiles for the training is attached in the drive.

# %% [markdown]
# ### Challenges

# %% [markdown]
# Observation - After training the model for clean, A1 - 20, A1 - 50, A1 - 80, A2 - 20 and A2 - 50, we get maximum caliberation error of 9. Logfiles are attached in the drive for episodes of 1000.
